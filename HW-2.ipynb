# %% [markdown]
# #### Русский текст
# Сложности в тексте: категория состояния/наречие/краткое прилагательное, существительное/наречие, прилагательное/существительное, глагол/сущетсвительное, частица/союз/местоимение, числительное/прилагательное, сравнительная степень,  частица/наречие

# %%
text="Антон Анатольевич, вылетевший внеплановым рейсом в Метелкино вчера утром, уже к вечеру смог начать осмотр больных. В первой палате было холодно. Во время прошлых визитов местные рассказывали ему, что здание госпиталя было построено в военные годы и до настоящего времени не видело ни одного капитального ремонта. Антон Анатольевич поёжился от холода и сел рядом с койкой молодого человека с перебинтованным боком. Увидев доктора, парень устало приоткрыл глаза и тихо вздохнул. «Нужно осмотреть рану», предупредил Антон Анатольевич. «Это быстро». Из кармана медицинского халата он достал ножницы и серьезно посмотрел на раненого. Тот поморщился, но через секунду его лицо вновь стало безразлично. Внезапно Антон Анатольевич почувствовал тяжесть в груди, во рту стало сухо. Проработавший в медицине тридцать четыре года, он не думал, что однажды будет снова так бояться на работе, да еще и без особой причины. Первый слой, второй, третий… Но каждым оборотом теряющая белый цвет марля насыщалась не красно-коричневым оттенком, а ярко-фиолетовым. Нитки слипались все сильнее, снимать бандаж безболезненно уже не получалось, и под тяжелое сопение больного показалось скользкое щупалце…"

# %% [markdown]
# Ручная разметка

# %% [markdown]
# NOUN - существительное<br>PRTF - полное причастие<br>PRTS - краткое причастие<br>ADJF - полное прилагательное<br>ADJS - краткое прилагательное<br>ADVB - наречие<br>ADVBC - сравнительная форма наречия<br>PREP - предлог<br>PRCL - частица<br>VERB - глагол<br>INFN - инфинитив<br>NUMR - числительное<br>CTGS - категория состояния<br>CONJ - союз<br>GRND - деепричастие<br>PPRP - притяжательное местоимение

# %%
#делаю словарь потому что
#у меня нет омонимочных слов разных частей речи
tagging_ruchk = {'Антон': 'NOUN', 'Анатольевич': 'NOUN', 'вылетевший': 'PRTF"', 'внеплановым': 'ADJF', 'рейсом': 'NOUN', 'в': 'PREP', 'Метелкино': 'NOUN', 'вчера': 'ADVB', 'утром': 'ADVB', 'уже': 'PRCL', 'к': 'PREP', 'вечеру': 'NOUN', 'смог': 'VERB', 'начать': 'INFN', 'осмотр': 'NOUN', 'больных': 'NOUN', 'первой': 'NUMR', 'палате': 'NOUN', 'было': 'VERB', 'холодно': 'CTGS', 'во': 'PREP', 'время': 'NOUN', 'прошлых': 'ADJF', 'визитов': 'NOUN', 'местные': 'NOUN', 'рассказывали': 'VERB', 'ему': 'PRP', 'что': 'CONJ', 'здание': 'NOUN', 'госпиталя': 'NOUN', 'построено': 'PRTS', 'военные': 'ADJF', 'годы': 'NOUN', 'и': 'CONJ', 'до': 'PREP', 'настоящего': 'ADJF', 'времени': 'NOUN', 'не': 'PRCL', 'видело': 'VERB', 'ни': 'PRCL', 'одного': 'NUMR', 'капитального': 'ADJF', 'ремонта': 'NOUN', 'поёжился': 'VERB', 'от': 'PREP', 'холода': 'NOUN', 'сел': 'VERB', 'рядом': 'ADVB', 'с': 'PREP', 'койкой': 'NOUN', 'молодого': 'ADJF', 'человека': 'NOUN', 'перебинтованным': 'PRTF', 'боком': 'NOUN', 'Увидев': 'GRND', 'Доктора': 'NOUN', 'парень': 'NOUN', 'устало': 'ADVB', 'приоткрыл': 'VERB', 'глаза': 'NOUN', 'тихо': 'ADVB', 'вздохнул': 'VERB', 'Нужно': 'CTGS', 'осмотреть': 'INFN', 'рану': 'NOUN', 'предупредил': 'VERB', 'Это': 'PRN', 'быстро': 'ADJS', 'Из': 'PREP', 'кармана': 'NOUN', 'медицинского': 'ADJF', 'халата': 'NOUN', 'он': 'PRP', 'достал': 'VERB', 'ножницы': 'NOUN', 'серьезно': 'ADVB', 'посмотрел': 'VERB', 'на': 'PREP', 'раненого': 'NOUN', 'тот': 'PRN', 'Поморщился': 'VERB', 'но': 'CONJ', 'через': 'PREP', 'секунду': 'NOUN', 'его': 'PPRP', 'лицо': 'NOUN', 'вновь': 'ADVB', 'стало': 'VERB', 'безразлично': 'ADJS', 'Внезапно': 'ADVB', 'Почувствовал': 'VERB', 'тяжесть': 'NOUN', 'груди': 'NOUN', 'рту': 'NOUN', 'сухо': 'ADJS', 'Проработавший': 'PRTF', 'медицине': 'NOUN', 'тридцать': 'NUMR', 'четыре': 'NUMR', 'года': 'NOUN', 'думал': 'VERB', 'однажды': 'ADVB', 'будет': 'VERB', 'снова': 'ADVB', 'так': 'ADVB', 'нервничать': 'INFN', 'работе': 'NOUN', 'да': 'CONJ', 'еще': 'PRCL', 'без': 'PRCL', 'особой': 'ADJF', 'причины': 'NOUN', 'Первый': 'NUMR', 'слой': 'NOUN', 'второй': 'NUMR', 'третий': 'NUMR', 'Но': 'CONJ', 'С': 'PREP', 'каждым': 'PRN', 'оборотом': 'NOUN', 'теряющая': 'PRTF', 'белый': 'ADJF', 'цвет': 'NOUN', 'марля': 'NOUN', 'насыщалась': 'VERB', 'красно-коричневым': 'ADJF', 'оттенком': 'NOUN', 'а': 'CONJ', 'ярко-фиолетовым': 'ADJF', 'Нитки': 'NOUN', 'слипались': 'VERB', 'все': 'PRCL', 'сильнее': 'ADVBC', 'снимать': 'INFN', 'бандаж': 'NOUN', 'безболезненно': 'ADVB', 'получалось': 'VERB', 'под': 'PREP', 'тяжелое': 'ADJF', 'сопение': 'NOUN', 'больного': 'NOUN', 'показалось': 'VERB', 'скользкое': 'ADJF', 'щупальце': 'NOUN'}

# %%
tagging_ruchk
# Out:
# {'Антон': 'NOUN',
#  'Анатольевич': 'NOUN',
#  'вылетевший': 'PRTF"',
#  'внеплановым': 'ADJF',
#  'рейсом': 'NOUN',
#  'в': 'PREP',
#  'Метелкино': 'NOUN',
#  'вчера': 'ADVB',
#  'утром': 'ADVB',
#  'уже': 'PRCL',
#  'к': 'PREP',
#  'вечеру': 'NOUN',
#  'смог': 'VERB',
#  'начать': 'INFN',
#  'осмотр': 'NOUN',
#  'больных': 'NOUN',
#  'первой': 'NUMR',
#  'палате': 'NOUN',
#  'было': 'VERB',
#  'холодно': 'CTGS',
#  'во': 'PREP',
#  'время': 'NOUN',
#  'прошлых': 'ADJF',
#  'визитов': 'NOUN',
#  'местные': 'NOUN',
#  'рассказывали': 'VERB',
#  'ему': 'PRP',
#  'что': 'CONJ',
#  'здание': 'NOUN',
#  'госпиталя': 'NOUN',
#  'построено': 'PRTS',
#  'военные': 'ADJF',
#  'годы': 'NOUN',
#  'и': 'CONJ',
#  'до': 'PREP',
#  'настоящего': 'ADJF',
#  'времени': 'NOUN',
#  'не': 'PRCL',
#  'видело': 'VERB',
#  'ни': 'PRCL',
#  'одного': 'NUMR',
#  'капитального': 'ADJF',
#  'ремонта': 'NOUN',
#  'поёжился': 'VERB',
#  'от': 'PREP',
#  'холода': 'NOUN',
#  'сел': 'VERB',
#  'рядом': 'ADVB',
# ...

# %% [markdown]
# **Тэггеры русского**

# %% [markdown]
# Pymorphy

# %%
import nltk
from nltk.tokenize import word_tokenize

words = [w.lower() for w in word_tokenize(text) if w.isalpha()]

# %%
from pymorphy2 import MorphAnalyzer
morph = MorphAnalyzer()

morph_li = []

for token in words:
    parsed = morph.parse(token)
    first = parsed[0]
    if first.tag.POS:
        morph_li.append((first.word, first.tag.POS))

# %%
morph_li
# Out:
# [('антон', 'NOUN'),
#  ('анатольевич', 'NOUN'),
#  ('вылетевший', 'PRTF'),
#  ('внеплановым', 'ADJF'),
#  ('рейсом', 'NOUN'),
#  ('в', 'PREP'),
#  ('метелкино', 'NOUN'),
#  ('вчера', 'ADVB'),
#  ('утром', 'ADVB'),
#  ('уже', 'ADVB'),
#  ('к', 'PREP'),
#  ('вечеру', 'NOUN'),
#  ('смог', 'VERB'),
#  ('начать', 'INFN'),
#  ('осмотр', 'NOUN'),
#  ('больных', 'ADJF'),
#  ('в', 'PREP'),
#  ('первой', 'ADJF'),
#  ('палате', 'NOUN'),
#  ('было', 'VERB'),
#  ('холодно', 'ADJS'),
#  ('во', 'PREP'),
#  ('время', 'NOUN'),
#  ('прошлых', 'NOUN'),
#  ('визитов', 'NOUN'),
#  ('местные', 'ADJF'),
#  ('рассказывали', 'VERB'),
#  ('ему', 'NPRO'),
#  ('что', 'CONJ'),
#  ('здание', 'NOUN'),
#  ('госпиталя', 'NOUN'),
#  ('было', 'VERB'),
#  ('построено', 'PRTS'),
#  ('в', 'PREP'),
#  ('военные', 'NOUN'),
#  ('годы', 'NOUN'),
#  ('и', 'CONJ'),
#  ('до', 'PREP'),
#  ('настоящего', 'ADJF'),
#  ('времени', 'NOUN'),
#  ('не', 'PRCL'),
#  ('видело', 'VERB'),
#  ('ни', 'PRCL'),
#  ('одного', 'ADJF'),
# ...

# %% [markdown]
# Mystem

# %%
from pymystem3 import Mystem

stem_li = []

m = Mystem()
ana = m.analyze(text)

for x in ana:
    if len(dict.keys(x)) == 2:
        stem_li.append((x['text'], x['analysis'][0]['gr'][0]))

# %%
stem_li
# Out:
# [('Антон', 'S'),
#  ('Анатольевич', 'S'),
#  ('вылетевший', 'V'),
#  ('внеплановым', 'A'),
#  ('рейсом', 'S'),
#  ('в', 'P'),
#  ('Метелкино', 'S'),
#  ('вчера', 'A'),
#  ('утром', 'S'),
#  ('уже', 'A'),
#  ('к', 'P'),
#  ('вечеру', 'S'),
#  ('смог', 'V'),
#  ('начать', 'V'),
#  ('осмотр', 'S'),
#  ('больных', 'S'),
#  ('В', 'P'),
#  ('первой', 'A'),
#  ('палате', 'S'),
#  ('было', 'V'),
#  ('холодно', 'A'),
#  ('Во', 'P'),
#  ('время', 'S'),
#  ('прошлых', 'A'),
#  ('визитов', 'S'),
#  ('местные', 'A'),
#  ('рассказывали', 'V'),
#  ('ему', 'S'),
#  ('что', 'C'),
#  ('здание', 'S'),
#  ('госпиталя', 'S'),
#  ('было', 'V'),
#  ('построено', 'V'),
#  ('в', 'P'),
#  ('военные', 'A'),
#  ('годы', 'S'),
#  ('и', 'C'),
#  ('до', 'P'),
#  ('настоящего', 'A'),
#  ('времени', 'S'),
#  ('не', 'P'),
#  ('видело', 'V'),
#  ('ни', 'P'),
#  ('одного', 'A'),
#  ('капитального', 'A'),
#  ('ремонта', 'S'),
#  ('Антон', 'S'),
#  ('Анатольевич', 'S'),
#  ('поёжился', 'V'),
#  ('от', 'P'),
# ...

# %% [markdown]
# Natasha

# %%
from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    
    PER,
    NamesExtractor,

    Doc
)

# %%
segmenter = Segmenter()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

# %%
doc = Doc(text)
doc.segment(segmenter)

# %%
doc.tag_morph(morph_tagger)
nata_li = []
for token in doc.tokens:
    nata_li.append((token.text, token.pos))

# %%
nata_li
# Out:
# [('Антон', 'PROPN'),
#  ('Анатольевич', 'PROPN'),
#  (',', 'PUNCT'),
#  ('вылетевший', 'VERB'),
#  ('внеплановым', 'ADJ'),
#  ('рейсом', 'NOUN'),
#  ('в', 'ADP'),
#  ('Метелкино', 'PROPN'),
#  ('вчера', 'ADV'),
#  ('утром', 'NOUN'),
#  (',', 'PUNCT'),
#  ('уже', 'ADV'),
#  ('к', 'ADP'),
#  ('вечеру', 'NOUN'),
#  ('смог', 'VERB'),
#  ('начать', 'VERB'),
#  ('осмотр', 'NOUN'),
#  ('больных', 'NOUN'),
#  ('.', 'PUNCT'),
#  ('В', 'ADP'),
#  ('первой', 'ADJ'),
#  ('палате', 'NOUN'),
#  ('было', 'AUX'),
#  ('холодно', 'ADJ'),
#  ('.', 'PUNCT'),
#  ('Во', 'ADP'),
#  ('время', 'NOUN'),
#  ('прошлых', 'ADJ'),
#  ('визитов', 'NOUN'),
#  ('местные', 'NOUN'),
#  ('рассказывали', 'VERB'),
#  ('ему', 'PRON'),
#  (',', 'PUNCT'),
#  ('что', 'SCONJ'),
#  ('здание', 'NOUN'),
#  ('госпиталя', 'NOUN'),
#  ('было', 'AUX'),
#  ('построено', 'VERB'),
#  ('в', 'ADP'),
#  ('военные', 'ADJ'),
#  ('годы', 'NOUN'),
#  ('и', 'CCONJ'),
#  ('до', 'ADP'),
#  ('настоящего', 'ADJ'),
#  ('времени', 'NOUN'),
# ...

# %% [markdown]
# #### Английский текст
# Сложности в тексте: наречие/существительное/глагол/прилагательное, глагол/существительное, деепричастие/существительное, существительное/прилагательное и т.д.

# %%
text = """Well done, students! – mrs. Ambroise said to class as she had finished her first lesson at St. Augustine High School. – I hope to see you tomorrow! 
Robby Blackwood smiled wryly. How is she so optimistic about everything? Probably that’s because she doesn’t know a single thing about being a teacher in their school. Or maybe she’s just faking it and tomorrow she will file a notice of voluntary dismissal. They are impossible to work with and she is a young French immigrant with little to no teaching practice. He almost felt sorry for her, but he was afraid that the feeling might grow into pity, so he grabbed his books and headed to lunch. Many days had passed until he started coming back to these thoughts…
"""

# %% [markdown]
# **Тэггеры английского**

# %% [markdown]
# Flair

# %%
import re
ss = re.split("\. |\.\.\. ", text)

# %%
from flair.data import Sentence
from flair.models import SequenceTagger

for s in ss:
    sentence = Sentence(s)

    tagger = SequenceTagger.load('pos')
    tagger.predict(sentence)

    print(sentence.to_tagged_string())
# Out:
# 2020-10-18 23:42:57,716 loading file /Users/uliamarkova/.flair/models/en-pos-ontonotes-v0.5.pt
# Антон <NFP> Анатольевич <NFP> , <,> вылетевший <NFP> внеплановым <NFP> рейсом <NFP> в <FW> Метелкино <FW> вчера <ADD> утром <NFP> , <,> уже <NFP> к <NFP> вечеру <NFP> смог <NFP> начать <NFP> осмотр <ADD> больных <NFP>
# 2020-10-18 23:42:59,742 loading file /Users/uliamarkova/.flair/models/en-pos-ontonotes-v0.5.pt
# В <NFP> первой <NFP> палате <NNP> было <NFP> холодно <NFP>
# 2020-10-18 23:43:00,998 loading file /Users/uliamarkova/.flair/models/en-pos-ontonotes-v0.5.pt
# Во <NFP> время <UH> прошлых <NFP> визитов <FW> местные <FW> рассказывали <FW> ему <FW> , <FW> что <FW> здание <FW> госпиталя <FW> было <FW> построено <FW> в <FW> военные <FW> годы <FW> и <FW> до <FW> настоящего <FW> времени <FW> не <FW> видело <FW> ни <FW> одного <FW> капитального <FW> ремонта <FW>
# 2020-10-18 23:43:03,571 loading file /Users/uliamarkova/.flair/models/en-pos-ontonotes-v0.5.pt
# ...

# %% [markdown]
# SpaCy

# %%
import spacy
nlp = spacy.load("en")
from spacy.lang.en import English
doc = nlp(text)
for i, s in enumerate(doc.sents):
    print("\n-- Sentence %d --" % i)
    for t in s:
        print(t.text, t.lemma_, t.pos_, sep="\t")
# Out:
# -- Sentence 0 --
# Well	well	INTJ
# done	do	VERB
# ,	,	PUNCT
# students	student	NOUN
# !	!	PUNCT
# –	–	PUNCT
#
# -- Sentence 1 --
# mrs	mrs	PROPN
# .	.	PROPN
#
# -- Sentence 2 --
# Ambroise	Ambroise	PROPN
# said	say	VERB
# to	to	ADP
# class	class	NOUN
# as	as	SCONJ
# she	-PRON-	PRON
# had	have	AUX
# finished	finish	VERB
# her	-PRON-	DET
# first	first	ADJ
# lesson	lesson	NOUN
# at	at	ADP
# St.	St.	PROPN
# Augustine	Augustine	PROPN
# High	High	PROPN
# School	School	PROPN
# .	.	PUNCT
#
# -- Sentence 3 --
# –	–	PUNCT
# I	-PRON-	PRON
# hope	hope	VERB
# to	to	PART
# see	see	VERB
# you	-PRON-	PRON
# tomorrow	tomorrow	NOUN
# !	!	PUNCT
#
#
# 	SPACE
#
# -- Sentence 4 --
# Robby	Robby	PROPN
# Blackwood	Blackwood	PROPN
# smiled	smile	VERB
# wryly	wryly	ADV
# .	.	PUNCT
#
# -- Sentence 5 --
# How	how	ADV
# is	be	AUX
# she	-PRON-	PRON
# so	so	ADV
# optimistic	optimistic	ADJ
# about	about	ADP
# everything	everything	PRON
# ?	?	PUNCT
#
# -- Sentence 6 --
# Probably	probably	ADV
# that	that	DET
# ...

# %% [markdown]
# NLTK

# %%
words = [w.lower() for w in word_tokenize(text) if w.isalpha()]
print(nltk.pos_tag(words))
# Out:
# [('well', 'RB'), ('done', 'VBN'), ('students', 'NNS'), ('ambroise', 'NN'), ('said', 'VBD'), ('to', 'TO'), ('class', 'NN'), ('as', 'IN'), ('she', 'PRP'), ('had', 'VBD'), ('finished', 'VBN'), ('her', 'PRP$'), ('first', 'JJ'), ('lesson', 'NN'), ('at', 'IN'), ('augustine', 'JJ'), ('high', 'JJ'), ('school', 'NN'), ('i', 'NNS'), ('hope', 'VBP'), ('to', 'TO'), ('see', 'VB'), ('you', 'PRP'), ('tomorrow', 'NN'), ('robby', 'VB'), ('blackwood', 'NN'), ('smiled', 'VBN'), ('wryly', 'JJ'), ('how', 'WRB'), ('is', 'VBZ'), ('she', 'PRP'), ('so', 'RB'), ('optimistic', 'JJ'), ('about', 'IN'), ('everything', 'NN'), ('probably', 'RB'), ('that', 'IN'), ('s', 'NN'), ('because', 'IN'), ('she', 'PRP'), ('doesn', 'VBZ'), ('t', 'NNS'), ('know', 'VBP'), ('a', 'DT'), ('single', 'JJ'), ('thing', 'NN'), ('about', 'IN'), ('being', 'VBG'), ('a', 'DT'), ('teacher', 'NN'), ('in', 'IN'), ('their', 'PRP$'), ('school', 'NN'), ('or', 'CC'), ('maybe', 'RB'), ('she', 'PRP'), ('s', 'VBZ'), ('just', 'RB'), ('faking', 'VBG'), 
# ...
